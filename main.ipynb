# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import plotly.io as pio
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
pio.renderers.default = 'browser'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import plotly.express as px
#
# ModuleNotFoundError: No module named 'numpy'

# %%
data = pd.read_csv("kc_house_data.csv")
data.head()
data2=data[data["sqft_living"]==780]
data2["price"].mean()
# Out:
# np.float64(243127.76923076922)

# %%
feature =data["sqft_living"].values
target =  data["price"].values

# %%
feature = feature.reshape(-1,1)
target = target.reshape(-1,1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(feature, target, test_size = 0.2, random_state = 0)
print(X_train)
print("X-Train :",X_train.shape)
print("X-Test :",X_test.shape)
print("Y-Train :",Y_test.shape)
print("Y-Test :",Y_test.shape)
# Out:
# [[1570]
#  [1780]
#  [1090]
#  ...
#  [2360]
#  [2370]
#  [2380]]
# X-Train : (17290, 1)
# X-Test : (4323, 1)
# Y-Train : (4323, 1)
# Y-Test : (4323, 1)

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize = (15,8))
plt.scatter(X_train, Y_train)
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.title('Price vs Sqft_living')
plt.xlabel('price')
plt.ylabel('square feet Living')
plt.show()

# %%
test_prdx=lr.predict(X_test)
test_prdx
# Out:
# array([[ 357817.97314081],
#        [1277876.09832343],
#        [ 360657.65871236],
#        ...,
#        [ 337940.17413995],
#        [ 221513.06570635],
#        [ 417451.37014338]])

# %%
result=pd.DataFrame(test_prdx,columns=['predicted'])
pd.options.display.float_format = '{:.2f}'.format
result['actual']=Y_test
result
# Out:
#       predicted     actual
# 0     357817.97  297000.00
# 1    1277876.10 1578000.00
# 2     360657.66  562100.00
# 3     272627.41  631500.00
# 4     854762.95  780000.00
# ...         ...        ...
# 4318  829205.78  844000.00
# 4319  309543.32  335500.00
# 4320  337940.17  369950.00
# 4321  221513.07  300000.00
# 4322  417451.37  575950.00
#
# [4323 rows x 2 columns]

# %%
print('Mean Absolute Error =', mean_absolute_error(Y_test, test_prdx))
# Out:
# Mean Absolute Error = 170780.92628145573

# %%
y = np.array(780)
y = y.reshape(-1, 1)

# Predicting on the basis of the value in 'y'
pred_y = lr.predict(y)
pred_y
# Out:
# array([[173238.41098997]])

# %%
print('The score obtained after studying for {} hours = {}'.format(y[0][0], pred_y[0][0]))
# Out:
# The score obtained after studying for 780 hours = 173238.41098997346
